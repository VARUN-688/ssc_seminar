# %%
import pandas as pd

# %%
d={'names':['rohan','sandesh','shreeharsha','theju','tushar','varun'],'usn':[80,88,102,117,118,124]}
df=pd.DataFrame(d,index=[f'4GM20CS{x}' for x in d["usn"]])
df
# Out:
#                   names  usn
# 4GM20CS80         rohan   80
# 4GM20CS88       sandesh   88
# 4GM20CS102  shreeharsha  102
# 4GM20CS117        theju  117
# 4GM20CS118       tushar  118
# 4GM20CS124        varun  124

# %%
s=pd.Series(['rohan','sandesh','shreeharsha','theju','tushar','varun'],name='TEAM',index=[80,88,102,117,118,124])
s
# Out:
# 80           rohan
# 88         sandesh
# 102    shreeharsha
# 117          theju
# 118         tushar
# 124          varun
# Name: TEAM, dtype: object

# %%
car_data=pd.read_csv(r"C:\Users\varun\PycharmProjects\ssc_presentation\car_data.csv")
car_data
# Out:
#      symboling  normalized_losses         make fuel_type aspiration  \
# 0            3                 41  alfa-romero       gas        std
# 1            3                 41  alfa-romero       gas        std
# 2            1                 41  alfa-romero       gas        std
# 3            2                164         audi       gas        std
# 4            2                164         audi       gas        std
# ..         ...                ...          ...       ...        ...
# 200         -1                 95        volvo       gas        std
# 201         -1                 95        volvo       gas      turbo
# 202         -1                 95        volvo       gas        std
# 203         -1                 95        volvo    diesel      turbo
# 204         -1                 95        volvo       gas      turbo
#
#     num_of_doors   body_style drive_wheels engine_location  wheel_base  ...  \
# ...

# %%
car_data.loc[0:100,].to_csv('car_data2.csv')
