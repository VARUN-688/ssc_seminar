# %%
import pandas as pd

# %%
df=pd.read_csv(r'C:\Users\varun\PycharmProjects\ssc_presentation\car_data2.csv',index_col=0)
df
# Out:
#      symboling  normalized_losses         make fuel_type aspiration  \
# 0            3                 41  alfa-romero       gas        std
# 1            3                 41  alfa-romero       gas        std
# 2            1                 41  alfa-romero       gas        std
# 3            2                164         audi       gas        std
# 4            2                164         audi       gas        std
# ..         ...                ...          ...       ...        ...
# 96           1                122       nissan       gas        std
# 97           1                103       nissan       gas        std
# 98           2                168       nissan       gas        std
# 99           0                106       nissan       gas        std
# 100          0                106       nissan       gas        std
#
#     num_of_doors   body_style drive_wheels engine_location  wheel_base  ...  \
# ...

# %%
df['make']
# Out:
# 0      alfa-romero
# 1      alfa-romero
# 2      alfa-romero
# 3             audi
# 4             audi
#           ...
# 96          nissan
# 97          nissan
# 98          nissan
# 99          nissan
# 100         nissan
# Name: make, Length: 101, dtype: object

# %%
df.loc[0:10,['make','fuel_type']]
# Out:
#            make fuel_type
# 0   alfa-romero       gas
# 1   alfa-romero       gas
# 2   alfa-romero       gas
# 3          audi       gas
# 4          audi       gas
# 5          audi       gas
# 6          audi       gas
# 7          audi       gas
# 8          audi       gas
# 9          audi       gas
# 10          bmw       gas

# %%
df[['make','fuel_type']].iloc[0:10]
# Out:
#           make fuel_type
# 0  alfa-romero       gas
# 1  alfa-romero       gas
# 2  alfa-romero       gas
# 3         audi       gas
# 4         audi       gas
# 5         audi       gas
# 6         audi       gas
# 7         audi       gas
# 8         audi       gas
# 9         audi       gas

# %%
df['symboling']=df['symboling']*24

# %%
df['symboling']
# Out:
# 0      72
# 1      72
# 2      24
# 3      48
# 4      48
#        ..
# 96     24
# 97     24
# 98     48
# 99      0
# 100     0
# Name: symboling, Length: 101, dtype: int64
