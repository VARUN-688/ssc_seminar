# %%
import pandas as pd

# %%
df=pd.read_csv(r'C:\Users\varun\PycharmProjects\ssc_presentation\car_data2.csv')

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'symboling', 'normalized_losses', 'make', 'fuel_type',
#        'aspiration', 'num_of_doors', 'body_style', 'drive_wheels',
#        'engine_location', 'wheel_base', 'length', 'width', 'height',
#        'curb_weight', 'engine_type', 'num-of_cylinders', 'engine_size',
#        'fuel_system', 'bore', 'stroke', 'compression_ratio', 'horsepower',
#        'peak_rpm', 'city_mpg', 'highway_mpg', 'price', 'price_binned'],
#       dtype='object')

# %%
df1=df.make.map(lambda x: x.upper())

# %%
df.make
df1
# Out:
# 0      ALFA-ROMERO
# 1      ALFA-ROMERO
# 2      ALFA-ROMERO
# 3             AUDI
# 4             AUDI
#           ...
# 96          NISSAN
# 97          NISSAN
# 98          NISSAN
# 99          NISSAN
# 100         NISSAN
# Name: make, Length: 101, dtype: object

# %%
df.num_of_doors.value_counts()
# Out:
# two     53
# four    48
# Name: num_of_doors, dtype: int64

# %%
def convert(row):
    d={'two':2,'four':4}
    #n=row.num_of_doors
    row.num_of_doors=d.get(row.num_of_doors)
    return row
df3=df.apply(convert,axis=1)
df3
# Out:
#      Unnamed: 0  symboling  normalized_losses         make fuel_type  \
# 0             0          3                 41  alfa-romero       gas
# 1             1          3                 41  alfa-romero       gas
# 2             2          1                 41  alfa-romero       gas
# 3             3          2                164         audi       gas
# 4             4          2                164         audi       gas
# ..          ...        ...                ...          ...       ...
# 96           96          1                122       nissan       gas
# 97           97          1                103       nissan       gas
# 98           98          2                168       nissan       gas
# 99           99          0                106       nissan       gas
# 100         100          0                106       nissan       gas
#
#     aspiration  num_of_doors   body_style drive_wheels engine_location  ...  \
# ...

# %%
df.describe
# Out:
# <bound method NDFrame.describe of      Unnamed: 0  symboling  normalized_losses         make fuel_type  \
# 0             0          3                 41  alfa-romero       gas
# 1             1          3                 41  alfa-romero       gas
# 2             2          1                 41  alfa-romero       gas
# 3             3          2                164         audi       gas
# 4             4          2                164         audi       gas
# ..          ...        ...                ...          ...       ...
# 96           96          1                122       nissan       gas
# 97           97          1                103       nissan       gas
# 98           98          2                168       nissan       gas
# 99           99          0                106       nissan       gas
# 100         100          0                106       nissan       gas
#
#     aspiration num_of_doors   body_style drive_wheels engine_location  ...  \
# ...

# %%
df.fuel_type.unique()
# Out:
# array(['gas', 'diesel'], dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101 entries, 0 to 100
# Data columns (total 28 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         101 non-null    int64
#  1   symboling          101 non-null    int64
#  2   normalized_losses  101 non-null    int64
#  3   make               101 non-null    object
#  4   fuel_type          101 non-null    object
#  5   aspiration         101 non-null    object
#  6   num_of_doors       101 non-null    object
#  7   body_style         101 non-null    object
#  8   drive_wheels       101 non-null    object
#  9   engine_location    101 non-null    object
#  10  wheel_base         101 non-null    float64
#  11  length             101 non-null    float64
#  12  width              101 non-null    float64
#  13  height             96 non-null     float64
#  14  curb_weight        101 non-null    int64
#  15  engine_type        101 non-null    object
# ...
